# %%
from cobra import Model,Reaction,Metabolite
model=Model('pathways_model')

# %%
import cobra
from escher import Builder

# %% [markdown]
# ## glycolysis

# %%
###==============>gluc
Glucin=Reaction("Glucin")
Glucin.name="GLucose import"
Glucin.lower_bound=1
Glucin.upper_bound=1

######## gluc+atp==========>g6p+adp+h

HK=Reaction("HK")
HK.name="Hexokinase"
HK.lower_bound=0
HK.upper_bound=1000

##########G6P<===========> F6P
#####phispho glucose isomerase/Glucose 6-phosphate isomerase G
PGI=Reaction("PGI")
PGI.name="GLucose 6-phosphate ismorase"
PGI.lower_bound=-1000
PGI.upper_bound=1000

####F6P + ATP =====> FDP + ADP + H+
#PHISPHO Fructose-kinase

PFK=Reaction("PFK")
PFK.name="Phosphofructokinase"
PFK.lower_bound=0
PFK.upper_bound=1000

###FDP(F1,6)<=======>G3P+DHAP
###Aldose

ALD=Reaction("ALD")
ALD.name="ALDOSE"
ALD.lower_bound=-1000
ALD.upper_bound=1000

###DHAP<======>G3P
##Triose-phosphate isomerase

TPI=Reaction("TPI")
TPI.name="Triose-phosphate isomerase"
TPI.lower_bound=-1000
TPI.upper_bound=1000

######GAP + NAD + Pi<=====>DPG13 + NADH + H+
GAPDH=Reaction("GAPDH")
GAPDH.name="H Glyceraldehyde 3-phosphate dehydrogenase"
GAPDH.lower_bound=-1000
GAPDH.upper_bound=1000

###### DPG13 + ADP ↔ PG3 + ATP

PGK=Reaction("PGK")
PGK.name="Phosphoglycerate kinase"
PGK.lower_bound=-1000
PGK.upper_bound=1000

###### PG3 ↔ PG2
PGLM=Reaction("PGLM")
PGLM.name="Phosphoglycerate  mutase"
PGLM.lower_bound=-1000
PGLM.upper_bound=1000

####PG2 ↔ PEP + H2O

ENO=Reaction("ENO")
ENO.name="Enolase"
ENO.lower_bound=-1000
ENO.upper_bound=1000

####PEP + ADP + H+ → PYR + ATP

PK=Reaction("PK")
PK.name="Pyruvate kinase"
PK.lower_bound=0
PK.upper_bound=1000

####PYR + NADH + H+ <==> LAC + NAD
LDH=Reaction("LDH")
LDH.name="Lactate dehydrogenase"
LDH.lower_bound=-1000
LDH.upper_bound=1000



####AMP ===>
AMPe=Reaction("AMP")
AMPe.name="AMP export"
AMPe.lower_bound=0
AMPe.upper_bound=1000


###2ADP  <===> AMP + ATP
APK=Reaction("APK")
APK.name="Adenylate kinase"
APK.lower_bound=-1000
APK.upper_bound=1000

## ====> AMP
AMPin=Reaction("AMPin")
AMPin.name="AMP import"
AMPin.lower_bound=1
AMPin.upper_bound=1


###ATP + H2O → ADP + Pi + H+

ATPh=Reaction("ATPh")
ATPh.name="ATP hydrolysis"
ATPh.lower_bound=0
ATPh.upper_bound=1000

### NADH ===> NAD + H+
NADHo=Reaction("NADHo")
NADHo.name="NADH oxidation"
NADHo.lower_bound=0
NADHo.upper_bound=1000


##PYR <===>
PYRe=Reaction("PYRe")
PYRe.name="Pyruvate exchange "
PYRe.lower_bound=-1000
PYRe.upper_bound=1000

### LAC <===>

LACe=Reaction("LACe")
LACe.name="Lactate exchange "
LACe.lower_bound=-1000
LACe.upper_bound=1000

### H <==>
He=Reaction("He")
He.name="Proton exchange "
He.lower_bound=-1000
He.upper_bound=1000


####H2O <====>
H2Oe=Reaction("H2O")
H2Oe.name="Water exchange "
H2Oe.lower_bound=-1000
H2Oe.upper_bound=1000


##D-Glucose exchange
D_Glucose_EX=Reaction("D_Glucose_EX")
D_Glucose_EX.name="D-Glucose exchange "
D_Glucose_EX.lower_bound=0
D_Glucose_EX.upper_bound=1000

# %%
#########metabolite
Gluc=Metabolite('Gluc',
               formula='C6H12O6',
               name='Glucose',
               compartment='c')

ATP=Metabolite('ATP',
               formula='C10H12N5O13P3',
               name='Adenosine tri-phosphate',
               compartment='c' )

G6P=Metabolite('G6P',
               formula='C6H13O9P',
               name='Glucose 6-phosphate',
               compartment='c' )

ADP=Metabolite('ADP',
               formula='C10H15N5O10P2',
               name='Adenosine di-phosphate',
               compartment='c' )
F6P=Metabolite('F6P',
               formula='C6H13O9P',
               name='Fructose 6-phosphate',
               compartment='c' )
H=Metabolite('H',
               formula='H',
               name='Proton',
               compartment='c' )
FDP=Metabolite('FDP',
               formula='C6H11Na3O12P2',
               name='Fructose 1,6-diphosphate',
               compartment='c' )

GAP=Metabolite('GAP',
               formula='H (O)CCH (OH)CH 2 OPO 32',
               name='Glyceraldehyde 3-phosphate',
               compartment='c' )

DHAP=Metabolite('DHAP',
               formula='HOCH 2 C (O)CH 2 OPO 32',
               name='Dihydroxyacetone phosphate',
               compartment='c' )

Pi=Metabolite('Pi',
               formula='PO4 3-',
               name='Inorganic phosphate',
               compartment='c' )
H2O=Metabolite('H2O',
               formula='H2O',
               name='Water',
               compartment='c' )
NAD=Metabolite('NAD',
               formula='C21H28N7O14P2+',
               name='Nicotinamide adenine dinucleotide (oxidized)',
               compartment='c' )
NADH=Metabolite('NADH',
               formula=' C21-H29-N7-O14-P2.2Na',
               name='Nicotinamide adenine dinucleotide (reduced)',
               compartment='c' )


AMP=Metabolite('AMP',
               formula='C10H14N5O7P',
               name='Adenosine mono-phosphate',
               compartment='c' )

DPG13=Metabolite('DPG13',
               formula='C3H8O10P2 · 5C6H13N',
               name='1,3-Diphosphoglycerate',
               compartment='c' )

PG3=Metabolite('PG3',
               formula='C3H7O7P',
               name='3-Phosphoglycerate',
               compartment='c' )

PG2=Metabolite('PG2',
               formula='C3H4O7P-3',
               name='2-Phosphoglycerate',
               compartment='c' )

PEP=Metabolite('PEP',
               formula='C3H5O6P',
               name='Phosphoenolpyruvate',
               compartment='c' )

PYR=Metabolite('PYR',
               formula='C3H3O3-',
               name='Pyruvate',
               compartment='c' )

LAC=Metabolite('LAC',
               formula='C3H5O6P',
               name='Lactate',
               compartment='c' )

# %%
##model.objective='PK'

# %% [markdown]
# ## pentose pathway

# %%
# ############reactions

####G6P+NADP → GL6P+NADPH + H
G6PDH=Reaction("G6PDH")
G6PDH.name="G6P dehydrogenase "
G6PDH.lower_bound=0
G6PDH.upper_bound=1000



####GL6P+H2O →GO6P + H
PGLase=Reaction("PGLase")
PGLase.name="6-Phosphogluconolactonase "
PGLase.lower_bound=0
PGLase.upper_bound=1000



####GO6P+NADP→ RU5P+NADPH+CO2
GL6PDH=Reaction("GL6PDH")
GL6PDH.name="GO6P dehydrogenase "
GL6PDH.lower_bound=0
GL6PDH.upper_bound=1000


####RU5P<->X5P
R5PE=Reaction("R5PE")
R5PE.name="R5PE epimerase "
R5PE.lower_bound=-1000
R5PE.upper_bound=1000


####RU5P<->R5P
R5PI=Reaction("R5PI")
R5PI.name="R5P isomerase "
R5PI.lower_bound=-1000
R5PI.upper_bound=1000



####X5P+R5P<->S7P + GAP
TKI=Reaction("TKI")
TKI.name="Transketolase I "
TKI.lower_bound=-1000
TKI.upper_bound=1000



####X5P+E4P<->F6P+GAP
TKII=Reaction("TKII")
TKII.name="Transketolase II "
TKII.lower_bound=-1000
TKII.upper_bound=1000



####S7P+GAP<->E4P+ F6P
TALA=Reaction("TALA")
TALA.name="Transaldolase "
TALA.lower_bound=-1000
TALA.upper_bound=1000


####GSSG+NADPH+H<->2GSH + NADP
GSSGR=Reaction("GSSGR")
GSSGR.name="Glutathione reductase "
GSSGR.lower_bound=-1000
GSSGR.upper_bound=1000



####GSSG+NADPH+H<->2GSH + NADP
GSHR=Reaction("GSHR")
GSHR.name="Glutathione oxidase "
GSHR.lower_bound=-1000
GSHR.upper_bound=1000




####CO2,in →CO2,out
CO2_exch=Reaction("CO2_exch")
CO2_exch.name="freely exchanging CO2 "
CO2_exch.lower_bound=-1000
CO2_exch.upper_bound=1000

# %%
###############metabolites 

GL6P=Metabolite('GL6P',
               formula='C₆H₁₃O₉P',
               name='6-Phosphogluconolactone',
               compartment='c' )



GO6P=Metabolite('GO6P',
               formula='C₆H₁₃O₉P',
               name='6-Phosphoglyconate',
               compartment='c' )

RU5P=Metabolite('Ru5P',
               formula='C₅H₁₁O₈P',
               name='Ribulose 5-phosphate',
               compartment='c' )

X5P=Metabolite('X5P',
               formula='C₅H₁₁O₈P',
               name='Xylose 5-phosphate',
               compartment='c' )



R5P=Metabolite('R5P',
               formula='C₅H₁₁O₈P',
               name='Ribose 5-phosphate',
               compartment='c' )


S7P=Metabolite('S7P',
               formula='C7H15O10P',
               name='Sedoheptulose 7-phosphate',
               compartment='c' )

E4P=Metabolite('E4P',
               formula='C₄H₉O₇P',
               name='Erythrose 4-phosphate',
               compartment='c' )

NADP=Metabolite('NADP',
               formula='C21H29N7NaO17P3+',
               name='Nicotinamide adenine',
               compartment='c' )


NADPH=Metabolite('NADPH',
               formula='C 21 H 30 N 7 O 17 P 3',
               name='Nicotinamide adenine dinucleotide phosphate (reduced)',
               compartment='c' )


GSH=Metabolite('GSH',
               formula='C₁₀H₁₇N₃O₆S',
               name='Glutathione (reduced',
               compartment='c' )


GSSG=Metabolite('GSSG',
               formula='C₂₀H₃₂N₆O₁₂S₂',
               name='Glutathione (oxidized)',
               compartment='c' )

CO2=Metabolite('CO2',
               formula='CO₂',
               name='Carbon dioxide',
               compartment='c' )

# %%
###pyruvate oxidation####
CoA= Metabolite('CoA',
               formula='C23H38N7O17P3S',
               name='Coenzyme A',
               compartment='c')


actyle_CoA=Metabolite('acetyl_CoA',
               formula='C23H38N7O17P3S',
               name='Acetyl-Coenzyme A',
               compartment='c')


acetaldehyde=Metabolite('acetaldehyde',
               formula='CH3CHO',
               name='acetaldehyde',
               compartment='c')


Pyruvate_dehydrogenase_complex=Reaction('Pyruvate_dehydrogenase_complex')
Pyruvate_dehydrogenase_complex.name='Pyruvate dehydrogenase complex'
Pyruvate_dehydrogenase_complex.lower_bound=-1000
Pyruvate_dehydrogenase_complex.upper_bound=1000

# %% [markdown]
# ## fermentation

# %%
PTAr=Reaction("PTAr")
PTAr.name='Phosphotransacetylase'
PTAr.lower_bound=-1000
PTAr.upper_bound=1000


actp=Metabolite('Acetyl_phosphate',
    name= "Acetyl phosphate",
    formula="C2H3O5P",
    compartment='c')



ACK=Reaction("ACK")
ACK.name='Acetate kinase'
ACK.lower_bound=-1000
ACK.upper_bound=1000


ac=Metabolite( 'Acetate',
    name= "Acetate",
    formula="C2H3O2",
    compartment='c')

# %% [markdown]
# ### TCA CYCLE

# %%
###oxaloacetate 
OXA=Metabolite('OXA',
               formula='C4H2O5',
               name='oxaloacetate',
               compartment='c')




#####citrate
CITR=Metabolite('CITR',
               formula='C6H5O7',
               name='citrate',
               compartment='c')



## D-threo-isocitrate
D_TH_IS=Metabolite('D_TH_IS',
               formula='C6H5O7',
               name='D-threo-isocitrate',
               compartment='c')





##oxidized [2Fe-2S]-[ferredoxin]
OX_FERO=Metabolite('OX_FERO',
               formula='Fe2S2',
               name='oxidized [2Fe-2S]-[ferredoxin]',
               compartment='c')


## reduced [2Fe-2S]-[ferredoxin]
RE_FERO=Metabolite('RE_FERO',
               formula='Fe2S2',
               name='reduced [2Fe-2S]-[ferredoxin]',
               compartment='c')


## succinyl-CoA
SUC_COA=Metabolite('SUC_COA',
               formula='C25H35N7O19P3S',
               name='succinyl-CoA',
               compartment='c')




#####2-oxoglutarate

OXGLU=Metabolite('OXGLU',
               formula='C5H4O5',
               name='2-oxoglutaratee',
               compartment='c')






###succinate
SUCC=Metabolite('SUCC',
               formula='C4H4O4',
               name='succinate',
               compartment='c')
##fumrate
fumarate= Metabolite('fumarate',
               formula='C4H4O4',
               name= 'fumarate',
               compartment='c')



##  (S)-malate
s_MA=Metabolite('S_MA',
               formula='C4H4O5',
               name='(S)-malate',
               compartment='c')

a_ubiquinone= Metabolite('a_ubiquinone',
               formula=' C59H90O4)',
               name='a ubiquinone',
               compartment='c')

a_ubiquinol= Metabolite('a_ubiquinol',
               formula=' C59H92O4)',
               name= 'a ubiquinol',
                compartment='c')

cis_acon = Metabolite(
        'acon_C_c',
        name="Cis-Aconitate",
        formula="C6H3O6",
        compartment='c'
)

# %%
##ATP citrate synthase
###citrate synthase
ATPCS=Reaction("ATPCS")
ATPCS.name="ATP citrate synthase"
ATPCS.lower_bound=-1000
ATPCS.upper_bound=1000
##Aconitate hydratase
AC_HY=Reaction("ADHE")
AC_HY.name="Aconitate hydratase"
AC_HY.lower_bound=-1000
AC_HY.upper_bound=1000
####Isocitrate dehydrogenase (NAD(+))
ISO_DHY=Reaction("ISO_DHY")
ISO_DHY.name="Isocitrate dehydrogenase (NAD(+))"
ISO_DHY.lower_bound=-1000
ISO_DHY.upper_bound=1000
### 2-oxoglutarate synthase 
OXGLU_SYN=Reaction("OXGLU_SYN")
OXGLU_SYN.name="2-oxoglutarate synthase"
OXGLU_SYN.lower_bound=-1000
OXGLU_SYN.upper_bound=1000
#####Succinyl-CoA:acetate CoA-transferase
SUCC_CoA=Reaction("SUCC_CoA")
SUCC_CoA.name="Succinyl-CoA:acetate CoA-transferase"
SUCC_CoA.lower_bound=-1000
SUCC_CoA.upper_bound=1000
### Succinate dehydrogenase (quinone)
SUC_DHY=Reaction("SUC_DHY")
SUC_DHY.name="Succinate dehydrogenase (quinone)"
SUC_DHY.lower_bound=-1000
SUC_DHY.upper_bound=1000
####S_mlate formation
S_MA=Reaction("S_MA")
S_MA.name="S_mlate formation"
S_MA.lower_bound=-1000
S_MA.upper_bound=1000
####melate hydrogenase
MA_HY=Reaction("MA_HY")
MA_HY.name="melate hydrogenase"
MA_HY.lower_bound=-1000
MA_HY.upper_bound=1000
###acetate exchange
Acetate_Ex=Reaction("Acetate_Ex")
Acetate_Ex.name="Acetate exchange"
Acetate_Ex.lower_bound=0
Acetate_Ex.upper_bound=1000
####Oxoglutarate exchange
Oxoglutarate_EX =Reaction("Oxoglutarate_EX")
Oxoglutarate_EX.name="Oxoglutarate  exchange"
Oxoglutarate_EX.lower_bound=0
Oxoglutarate_EX.upper_bound=1000
###phosphate exchange
Phosphate_EX=Reaction("Phosphate_EX")
Phosphate_EX.name="Phosphate exchange"
Phosphate_EX.lower_bound=-1000
Phosphate_EX.upper_bound=1000
##Succinate exchange
Succinate_EX=Reaction("Succinate_EX")
Succinate_EX.name="Succinate exchange"
Succinate_EX.lower_bound=0
Succinate_EX.upper_bound=1000
##### cit_c ⇌ acon_C_c + h2o_c
ACONTa=Reaction('ACONTa') 
ACONTa.name='Aconitase (half-reaction A, Citrate hydro-lyase)'
ACONTa.lower_bound=-1000
ACONTa.upper_bound=1000
 ##### acon_C_c + h2o_c ⇌ icit_c
ACONTb=Reaction('ACONTb')
ACONTb.name='Aconitase (half-reaction B, Isocitrate hydro-lyase)'
ACONTb.lower_bound=-1000
ACONTb.upper_bound=1000

# %% [markdown]
# ## Oxidative phosphorylation

# %%
######## a ubiquinone + 5 H+(in) + NADH = a ubiquinol + 4 H+(out) + NAD+
ubiquinone=Reaction("ubiquinone")
ubiquinone.name="ubiquinone"
ubiquinone.lower_bound=0
ubiquinone.upper_bound=1000
######## a ubiquinone + succinate = a ubiquinol + fumarate
quinone=Reaction("quinone")
quinone.name="quinone"
quinone.lower_bound=0
quinone.upper_bound=1000
##Fumarate exchange
Fumarate_EX=Reaction("Fumarate_EX")
Fumarate_EX.name="Fumarate_EXchange"
Fumarate_EX.lower_bound=0
Fumarate_EX.upper_bound=1000
######## a quinol + 2 Fe(III)-[cytochrome c](out) = a quinone + 2 Fe(II)-[cytochrome c](out) + 2 H+(out)
Quinol_cytochrome=Reaction("Quinol_cytochrome")
Quinol_cytochrome.name="Quinol cytochrome c reductase"
Quinol_cytochrome.lower_bound=0
Quinol_cytochrome.upper_bound=1000
######## 4 Fe(II)-[cytochrome c] + 8 H+(in) + O2 = 4 Fe(III)-[cytochrome c] + 4 H+(out) + 2 H2O
Cytochrome_c_oxidase=Reaction("Cytochrome_c_oxidase")
Cytochrome_c_oxidase.name="Cytochrome c oxidase"
Cytochrome_c_oxidase.lower_bound=0
Cytochrome_c_oxidase.upper_bound=1000
########ATP + 4 H+(in) + H2O = ADP + 5 H+(out) + phosphate
H_transporting_two_sector_ATPase=Reaction("H_transporting_two_sector_ATPase")
H_transporting_two_sector_ATPase.name="H_transporting_two_sector_ATPase"
H_transporting_two_sector_ATPase.lower_bound=-1000
H_transporting_two_sector_ATPase.upper_bound=1000
########diphosphate + H2O = H+ + 2 phosphate
Inorganic_diphosphatase=Reaction("Inorganic_diphosphatase")
Inorganic_diphosphatase.name="Inorganic diphosphatase"
Inorganic_diphosphatase.lower_bound=0
Inorganic_diphosphatase.upper_bound=1000
########[phosphate](n) + ATP = [phosphate](n+1) + ADP
ATP_PHF=Reaction("ATP_PHF")
ATP_PHF.name="ATP-polyphosphate phosphotransferase"
ATP_PHF.lower_bound=-1000
ATP_PHF.upper_bound=1000
###"S_Malate exchange"
S_Malate_EX=Reaction("S_Malate_EX")
S_Malate_EX.name="S_Malate exchange"
S_Malate_EX.lower_bound=0
S_Malate_EX.upper_bound=1000
##oxygen exchange
O2_EX=Reaction("O2_EX")
O2_EX.name="oxygen exchange"
O2_EX.lower_bound=-1000
O2_EX.upper_bound=1000

# %%
a_quinol= Metabolite('a_quinol',
               formula=' C6H6O2)',
               name= 'quinol',
               compartment='c')


succinate= Metabolite('succinate',
               formula=' C4HO4)',
               name= 'succinate',
               compartment='c')

fumarate= Metabolite('fumarate',
               formula=' C4H4O4)',
               name= 'fumarate',
               compartment='c')


a_quinone=Metabolite('a_quinone',
               formula=' C6H4O2)',
               name= 'quinone',
               compartment='c')

Fe3= Metabolite('Fe3',
               formula=' FE2O3)',
               name= 'Fe3',
               compartment='c')

Fe2= Metabolite('Fe2',
               formula=' FeO',
               name= 'Fe2',
               compartment='c')
    
 
O2= Metabolite('O2',
               formula=' O2',
               name= 'oxgen',
               compartment='c')





PH= Metabolite('PH',
               formula='PO43-',
               name= 'phosphate',
               compartment='c')
    




DiPH= Metabolite('DiPH',
               formula=' H4O7P2',
               name= 'DI phosphate',
               compartment='c')

# %%
builder = Builder(
    map_name='e_coli_core.Core metabolism',
    model_name='e_coli_core',
)

# %% [markdown]
# # biomass

# %%
Biomass=Reaction("BioMass")
Biomass.name="Biomass Objective Function with GAM"
Biomass.lower_bound=0
Biomass.upper_bound=1000

# %%
##### REACTIONS  #####
###GLUCOSE######
Glucin.add_metabolites({Gluc:1,}) #
AMPin.add_metabolites({AMP:1})#
HK.add_metabolites({Gluc:-1,ATP:-1,ADP:1,G6P:1,H:1})#
PGI.add_metabolites({G6P:-1,F6P:1})#
PFK.add_metabolites({F6P:-1,FDP:1,ATP:-1,ADP:1,H:1})#
ALD.add_metabolites({FDP:-1,GAP:1,DHAP:1})#
TPI.add_metabolites({DHAP:-1,GAP:1,})#
GAPDH.add_metabolites({GAP:-1,NAD:-1,Pi:-1,DPG13:1,NADH:1,H:1})#
PGK.add_metabolites({DPG13:-1,ADP:-1,PG3:1,ATP:1})#
PGLM.add_metabolites({PG3:-1,PG2:1})#
ENO.add_metabolites({PG2:-1,PEP:1,H2O:1})#
PK.add_metabolites({PEP:-1,ADP:-1,H:-1,PYR:1,ATP:1})#
LDH.add_metabolites({PYR:-1,NADH:-1,H:-1,LAC:1,NAD:1})#
AMPe.add_metabolites({AMP:-1})#
APK.add_metabolites({ADP:-2,AMP:1,ATP:1})#
ATPh.add_metabolites({ATP:-1,H2O:-1,ADP:1,H:1,Pi:1})#
NADHo.add_metabolites({NADH:-1,NAD:1,H:1})#

####PENTOSE###
##G6P+NADP → GL6P+NADPH + H
G6PDH.add_metabolites({G6P:-1,NADP:-1,GL6P:1,H:1,NADPH:1})
##GL6P+H2O →GO6P + H
PGLase.add_metabolites({GL6P:-1,H2O:-1,GO6P:1,H:1})
##GO6P+NADP→ RU5P+NADPH+CO2
GL6PDH.add_metabolites({GO6P:-1,NADP:-1,RU5P:1,NADPH:1,CO2:1})
##RU5P<->X5P
R5PE.add_metabolites({RU5P:-1,X5P:1})
##RU5P<->R5P
R5PI.add_metabolites({RU5P:-1,R5P:1})
#######X5P+R5P<->S7P + GAP
TKI.add_metabolites({X5P:-1,R5P:-1,S7P:1,GAP:1})
#####X5P+E4P<->F6P+GAP
TKII.add_metabolites({X5P:-1,E4P:-1,F6P:1,GAP:1 })
##S7P+GAP<->E4P+ F6P
TALA.add_metabolites({S7P:-1,GAP:-1,E4P:1,F6P:1 })
####GSSG+NADPH+H<->2GSH + NADP
GSSGR.add_metabolites({GSSG:-1,NADPH:-1,H:-1,GSH:2,NADP:1 })
###2GSH<->GSSG + 2H
GSHR.add_metabolites({GSH:-2,GSSG:1,H:2 })


####pyruvate oxidation##
Pyruvate_dehydrogenase_complex.add_metabolites({PYR:-1,NAD:-1,CoA:-1,actyle_CoA:1,CO2:1,NADH:1})#


###fermentation###
PTAr.add_metabolites({actyle_CoA:-1,Pi:-1,CoA:-1,actp:1})#
ACK.add_metabolites({actp:-1,ADP:-1,ac:1,ATP:1})#


###TCA CYCLE###
##acetyl-CoA + ADP + oxaloacetate + phosphate = ATP + citrate + CoA
ATPCS.add_metabolites({actyle_CoA:-1,OXA:-1,H2O:-1,CITR:1,CoA:1})
ACONTa.add_metabolites({CITR:-1,cis_acon:1,H2O:1})
ACONTb.add_metabolites({cis_acon:-1,H2O:-1,D_TH_IS:1}) 
#####D-threo-isocitrate + NAD+ = 2-oxoglutarate + CO2 + NADH
ISO_DHY.add_metabolites({D_TH_IS:-1,NAD:-1,OXGLU:1,CO2:1,NADH:1,H:1})
## 2-oxoglutarate + CoA + 2 oxidized [2Fe-2S]-[ferredoxin] → CO2 + H+ + 2 reduced [2Fe-2S]-[ferredoxin] + succinyl-CoA
OXGLU_SYN.add_metabolites({OXGLU:-1,CoA:-1,NAD:-1,SUC_COA:1,CO2:1,NADH:1,H:1})
##acetate + succinyl-CoA = acetyl-CoA + succinate
SUCC_CoA.add_metabolites({ADP:-1,Pi:-1,SUC_COA:-1,SUCC:1,CoA:1,ATP:1})
## a ubiquinone + succinate = a ubiquinol + fumarate---->oxidative
SUC_DHY.add_metabolites({a_ubiquinol:-1,SUCC:-1,a_ubiquinone:1, fumarate:1})#
####(S)-malate = fumarate + H2O
S_MA.add_metabolites({fumarate:-1,H2O:-1,s_MA:1})
####(S)-malate + NAD+ = H+ + NADH + oxaloacetate
MA_HY.add_metabolites({s_MA:-1,NAD:-1,H:1,NADH:1,OXA:1})

########OXIDATIVE######
quinone.add_metabolites({a_ubiquinone:-1, succinate:-1,a_ubiquinol:1,fumarate:1})#
Quinol_cytochrome.add_metabolites({a_ubiquinol:-1, Fe3:-2,a_ubiquinone:1,Fe2:2,H:2})#
Cytochrome_c_oxidase.add_metabolites({Fe2:-4, H:-8,O2:-1,Fe3:4,H:4,H2O:2})#
H_transporting_two_sector_ATPase.add_metabolites({ATP:-1, H:-4,H2O:-1,ADP:1,H:5,Pi:1})#
Inorganic_diphosphatase.add_metabolites({DiPH:-1,H2O:-1,H:1,Pi:2})#
ATP_PHF.add_metabolites({Pi:-1,ATP:-1,Pi:2,ADP:1})#
ubiquinone.add_metabolites({a_ubiquinone:-1, NADH:-1,H:-5,a_ubiquinol:1,NAD:1,H:4})

###BIOMASS###
Biomass.add_metabolites({PG3:-1.496,actyle_CoA:-3.7478,ADP:59.81,
                         OXGLU:4.1182,ATP:-59.81,CoA:3.7478,E4P:-0.361,
                         F6P:-0.0709,GAP:-0.129,G6P:-0.205,
                         H2O:-59.81,H:59.81,NAD:-3.547,
                         NADH:3.547,NADP:13.0279,NADPH:-13.0279,OXA:-1.7867,PEP:-0.5191,Pi:59.81,PYR:-2.8328,R5P:-0.8977})

# %% [markdown]
# # exchange reactions

# %%
##carbon exchange
CO2_exch.add_metabolites({CO2:-1})#
##glucose exchange
D_Glucose_EX.add_metabolites({Gluc:-1})#
# pyruvate exchange
PYRe.add_metabolites({PYR:-1})#
#lactate exchange
LACe.add_metabolites({LAC:-1})#
#hydrogen exchange
He.add_metabolites({H:-1})#
#water exchange
H2Oe.add_metabolites({H2O:-1})#
#mlate exchange
S_Malate_EX.add_metabolites({s_MA:-1})#
###Acetate_Ex 
Acetate_Ex.add_metabolites({ac:-1})#
### Oxoglutarate exchange 
Oxoglutarate_EX.add_metabolites({OXGLU:-1})#
###Phosphate_EXchange
Phosphate_EX.add_metabolites({Pi:-1})#
###Succinate_EXchange
Succinate_EX.add_metabolites({SUCC:-1})#
#fumarate exchange
Fumarate_EX.add_metabolites({fumarate:-1})#
#oxygen exchange
O2_EX.add_metabolites({O2:-1})#

# %%
model.add_reactions([Glucin,PGI,HK,PFK,ALD,TPI,GAPDH,PGK,PGLM,ENO,LDH,AMPe,ATPh,NADHo,PK,APK,AMPin])
model.add_reactions([G6PDH,PGLase,GL6PDH,R5PE,R5PI,TKI,TKII,TALA,GSSGR,GSHR])
model.add_reactions([Pyruvate_dehydrogenase_complex])
model.add_reactions([PTAr,ACK])
model.add_reactions([ACONTa,ACONTb,ATPCS,ISO_DHY,OXGLU_SYN,SUCC_CoA,SUC_DHY,S_MA,MA_HY])
model.add_reactions([ATP_PHF,Inorganic_diphosphatase,H_transporting_two_sector_ATPase,Cytochrome_c_oxidase,Quinol_cytochrome,quinone,ubiquinone])

model.add_reactions([O2_EX,PYRe,He,LACe,H2Oe,D_Glucose_EX,S_Malate_EX,CO2_exch,Fumarate_EX,Succinate_EX,Acetate_Ex,Oxoglutarate_EX,Phosphate_EX,Biomass])
# Out:
# Ignoring reaction 'Glucin' since it already exists.
# Ignoring reaction 'PGI' since it already exists.
# Ignoring reaction 'HK' since it already exists.
# Ignoring reaction 'PFK' since it already exists.
# Ignoring reaction 'ALD' since it already exists.
# Ignoring reaction 'TPI' since it already exists.
# Ignoring reaction 'GAPDH' since it already exists.
# Ignoring reaction 'PGK' since it already exists.
# Ignoring reaction 'PGLM' since it already exists.
# Ignoring reaction 'ENO' since it already exists.
# Ignoring reaction 'LDH' since it already exists.
# Ignoring reaction 'AMP' since it already exists.
# Ignoring reaction 'ATPh' since it already exists.
# Ignoring reaction 'NADHo' since it already exists.
# Ignoring reaction 'PK' since it already exists.
# Ignoring reaction 'APK' since it already exists.
# Ignoring reaction 'AMPin' since it already exists.
# Ignoring reaction 'G6PDH' since it already exists.
# Ignoring reaction 'PGLase' since it already exists.
# ...

# %%
model.objective='BioMass'

# %%
model.optimize()
# Out:
# <Solution 0.428 at 0x1921a2d88b0>

# %%
build=Builder()
sol=model.optimize()
build.reaction_data=sol.fluxes

cobra.io.save_json_model(model,"model3.json")

# %%
build
# Out:
# Builder(reaction_data={'Glucin': 1.0, 'PGI': 0.9122694398082766, 'HK': 1.0, 'PFK': 0.5743142037916721, 'ALD': …
